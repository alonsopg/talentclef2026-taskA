# %% [markdown]
# # TalentCLEF 2026 Task A - JobBERT Dense Runs
#
# This notebook runs a clean bilingual JobBERT baseline for the English and Spanish Task A data.
#
# What it writes:
# - development-set TREC runs under `var/artifacts/jobbert_dense/`
# - development metrics CSV with `nDCG`, `MRR`, `P`, `Recall`, `F1`, and `MAP`
# - test-set TREC runs under `var/artifacts/jobbert_dense/`
# - Codabench-ready test files under `var/artifacts/jobbert_submission/`
# - a flat ZIP containing `run_en-en_TEAMNAME.trec` and `run_es-es_TEAMNAME.trec`
#
# The script validates on `data/development/...` and generates the final submission files from `data/test/...`.
#
# Change `TEAM_NAME` before producing an official upload package.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "task_a_jobbert_dense_en_es.py").exists():
    if (PROJECT_ROOT.parent / "task_a_jobbert_dense_en_es.py").exists():
        PROJECT_ROOT = PROJECT_ROOT.parent
    else:
        raise RuntimeError("Run this notebook from the repository root or the notebooks/ directory.")

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from task_a_jobbert_dense_en_es import main

TEAM_NAME = "yourteam"  # change this before an official submission
APPROACH_ID = "jobbert_dense_at50"

metrics_df = main(team_name=TEAM_NAME, approach_id=APPROACH_ID, k=50)
metrics_df
